# %%
import json
import glob
import pandas as pd

RUNS = []
for file in glob.glob("dumped-results/*.json"):
    with open(file) as f:
        data = json.load(f)
        c = list(data.keys())[0]
    RUNS.append({"corpus": c.split("--")[0], "model": c.split("--")[-1], **data[c]})
# print(RUNS[-1])
df = pd.DataFrame(RUNS)
filtered = df[df["corpus"] == "model"][["model", "fscore", "fscore-positive", "recall-positive", "precision-positive"]].sort_values(by="fscore-positive")

# %%
def whatisenriched(val):
    if "LinearEnriched" in val:
        return "Linear"
    if "EnriLSTM" in val:
        return "LSTM"
    if "EnriAttention" in val:
        return "Attention"
    return ""
def whatismsd(val):
    if "AggloMSD" in val:
        return "Agglo."
    if "NoMorph" in val:
        return ""
    return "Split"
def whatisencoder(val):
    if "EnriLSTM" in val:
        return "LSTM"
    if "EnriAttention" in val:
        return "Attention"
    if "HAN" in val:
        return "HAN"
    if "HAN" in val:
        return "HAN"
    if "AttentPool" in val:
        return "AttentPool"
    return ""

def whatmetadata(val):
    enriched = whatisenriched(val)
    if not enriched:
        return ""
    if "NoAuthorCitation" in val:
        return "Form,Century"
    if "NoAuthor" in val:
        return "Form,Century,Citation"
    return "All"
    
def whatmodel(val):
    if "FastText" in val:
        return "FastText"
    elif "Pretrained" in val:
        return "Word2Vec"
    return ""

filtered["Enriched"] = [whatisenriched(val) for val in filtered["model"]]
filtered["MSD"] = [whatismsd(val) for val in filtered["model"]]
filtered["Encoder"] = [whatisencoder(val) for val in filtered["model"]]
filtered["Metadata"] = [whatmetadata(val) for val in filtered["model"]]
filtered["Pretrained"] = [whatmodel(val) for val in filtered["model"]]
filtered["Bert"] = filtered["model"].str.contains("Bert")



filtered
# Out:
#                                                 model    fscore  \
# 7                      LinearBertTokenOnlyWithHighway  0.775342
# 4                                 LinearBertTokenOnly  0.780217
# 3         LinearVanillaAggloMSD-AttentPool-Pretrained  0.820632
# 12                          LinearVanillaAggloMSD-HAN  0.852922
# 2                               LinearVanillaAggloMSD  0.856086
# 10                LinearVanillaAggloMSD-EnriAttention  0.855392
# 11                                      LinearVanilla  0.862193
# 1                  LinearVanillaAggloMSD-Metatoks-HAN  0.865933
# 8                LinearVanillaAggloMSD-HAN-Pretrained  0.866852
# 0      LinearVanillaAggloMSD-EnriAttention-Pretrained  0.867753
# 13                                LinearBertLemma-HAN  0.869076
# 15                   LinearVanillaAggloMSD-AttentPool  0.878499
# 9                    LinearVanillaAggloMSD-Pretrained  0.882740
# 6                      LinearVanillaAggloMSD-EnriLSTM  0.889782
# 14  LinearVanilla-NoMorph-EnriLSTM-Pretrained-NoAu...  0.894032
# 5   LinearVanillaAggloMSD-EnriLSTM-Pretrained-NoAu...  0.897084
# 16          LinearVanillaAggloMSD-EnriLSTM-Pretrained  0.908608
#
#     fscore-positive  recall-positive  precision-positive   Enriched     MSD  \
# 7          0.582474         0.450199            0.824818              Split
# 4          0.593137         0.482072            0.770701              Split
# 3          0.668281         0.549801            0.851852             Agglo.
# 12         0.730088         0.657371            0.820895             Agglo.
# 2          0.735160         0.641434            0.860963             Agglo.
# 10         0.735729         0.693227            0.783784  Attention  Agglo.
# 11         0.747253         0.677291            0.833333              Split
# 1          0.754797         0.705179            0.811927             Agglo.
# 8          0.755556         0.677291            0.854271             Agglo.
# 0          0.758030         0.705179            0.819444  Attention  Agglo.
# 13         0.760259         0.701195            0.830189              Split
# 15         0.777293         0.709163            0.859903             Agglo.
# 9          0.785408         0.729084            0.851163             Agglo.
# 6          0.799180         0.776892            0.822785       LSTM  Agglo.
# 14         0.806653         0.772908            0.843478       LSTM
# 5          0.812371         0.784861            0.841880       LSTM  Agglo.
# 16         0.832981         0.784861            0.887387       LSTM  Agglo.
#
#        Encoder               Metadata Pretrained   Bert
# 7                                                  True
# 4                                                  True
# 3   AttentPool                          Word2Vec  False
# 12         HAN                                    False
# 2                                                 False
# 10   Attention                    All             False
# 11                                                False
# 1          HAN                                    False
# 8          HAN                          Word2Vec  False
# 0    Attention                    All   Word2Vec  False
# 13         HAN                                     True
# 15  AttentPool                                    False
# 9                                       Word2Vec  False
# 6         LSTM                    All             False
# 14        LSTM  Form,Century,Citation   Word2Vec  False
# 5         LSTM  Form,Century,Citation   Word2Vec  False
# 16        LSTM                    All   Word2Vec  False
