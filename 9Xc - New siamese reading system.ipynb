# %%
from seligator.dataset.readers import ClassificationTsvReader
import logging

logger = logging.getLogger()
logger.setLevel(logging.INFO)

reader = ClassificationTsvReader(
    token_features=("lemma", "lemma_char"),
    msd_features=("pos", "tense", "case"),  # siamese=True,
    # bert_dir="./bert/latin_bert",
    agglomerate_msd=True,
    instance_type="siamese",
    #metadata_encoding=MetadataEncoding.AS_CATEGORICAL,
    #metadata_tokens_categories=["Century", "WrittenType"]
)
dataset = list(reader.read(
    "dataset/main/train.txt",
    #default_metadata_tokens=["Century=4", "WrittenType=prose"]
))

print("type of its first element: ", type(dataset[0]))
print("size of dataset: ", len(dataset))
print(dataset[0])
# Out:
# 2021-08-16 17:33:03.198291: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# INFO:root:Dataset reader set with following categories: [msd], lemma, lemma_char
# /home/thibault/dev/est-lascivuum-non-est/env/lib/python3.8/site-packages/allennlp/data/token_indexers/token_characters_indexer.py:55: UserWarning: You are using the default value (0) of `min_padding_length`, which can cause some subtle bugs (more info see https://github.com/allenai/allennlp/issues/1954). Strongly recommend to set a value, usually the maximum size of the convolutional layer size when using CnnEncoder.
#   warnings.warn(
# INFO:root:Indexer set for following categories: [msd], lemma, lemma_char
# WARNING:root:TSV READER uses following metadata encoding MetadataEncoding.IGNORE
# WARNING:root:TSV Reader keeps following metadata
# WARNING:allennlp.data.fields.multilabel_field:Your label namespace was '[msd]'. We recommend you use a namespace ending with 'labels' or 'tags', so we don't add UNK and PAD tokens by default to your vocabulary.  See documentation for `non_padded_namespaces` parameter in Vocabulary.
# INFO:root:Triplet/Pairs are loaded from cache
# type of its first element:  <class 'allennlp.data.instance.Instance'>
# size of dataset:  21953
# Instance with fields:
#  	 left_[msd]: ListField of 26 MultiLabelFields :
#  	 MultiLabelField with labels: ['pos:CONcoo', 'case:-', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:PRE', 'case:-', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:PROind', 'case:Abl', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:NOMcom', 'case:Abl', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:PRE', 'case:-', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:NOMpro', 'case:Gen', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:NOMcom', 'case:Acc', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:PRE', 'case:-', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:ADJqua', 'case:Acc', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:NOMcom', 'case:Acc', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:VER', 'case:-', 'tense:Pres'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:PUNC', 'case:-', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:PRE', 'case:-', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:PROrel', 'case:Abl', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:NOMpro', 'case:Nom', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:ADV', 'case:-', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:VER', 'case:Nom', 'tense:Perf'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:NOMpro', 'case:Gen', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:NOMcom', 'case:Abl', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:NOMpro', 'case:Acc', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:NOMcom', 'case:Acc', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:NOMcom', 'case:Acc', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:ADJord', 'case:Abl', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:ADJord', 'case:Abl', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:VER', 'case:-', 'tense:Perf'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:PUNC', 'case:-', 'tense:-'] in namespace: '[msd]'.'
#
#  	 left_lemma: TextField of length 26 with text:
#  		[at2, ex, alter, pars, per, Ligures, ora, in, Narbonensis, prouincia, pergo, ,, in, qui1, Phocaenes,
# 		quondam, fugo, Persae, aduentus, Massilia, urbs, Olympias, quadragesimus, quintus, condo, .]
#  		and TokenIndexers : {'lemma': 'SingleIdTokenIndexer'}
#  	 left_lemma_char: TextField of length 26 with text:
#  		[at2, ex, alter, pars, per, Ligures, ora, in, Narbonensis, prouincia, pergo, ,, in, qui1, Phocaenes,
# 		quondam, fugo, Persae, aduentus, Massilia, urbs, Olympias, quadragesimus, quintus, condo, .]
#  		and TokenIndexers : {'lemma_char': 'TokenCharactersIndexer'}
#  	 left_label: LabelField with label: negative in namespace: 'labels'.
#  	 left_metadata: MetadataField (print field.metadata to see specific information).
#  	 right_[msd]: ListField of 18 MultiLabelFields :
#  	 MultiLabelField with labels: ['pos:PROrel', 'case:Nom', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:ADVneg', 'case:-', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:PROper', 'case:Acc', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:VER', 'case:-', 'tense:Perf'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:PRE', 'case:-', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:NOMcom', 'case:Abl', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:CONsub', 'case:-', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:VER', 'case:-', 'tense:Impa'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:PROper', 'case:Dat', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:NOMcom', 'case:Nom', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:PROpos', 'case:Nom', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:NOMcom', 'case:Nom', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:CONcoo', 'case:-', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:NOMcom', 'case:Nom', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:PROdem', 'case:Gen', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:VER', 'case:Nom', 'tense:Perf'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:ADJqua', 'case:Nom', 'tense:-'] in namespace: '[msd]'.'
#  	 MultiLabelField with labels: ['pos:PUNC', 'case:-', 'tense:-'] in namespace: '[msd]'.'
#
#  	 right_lemma: TextField of length 18 with text:
#  		[qui1, non, ego, interficio, ab, uulua, ut4, fio, ego, mater, meus, sepulcrum, et2, uulua, is,
# 		concipio, aeternus, .]
#  		and TokenIndexers : {'lemma': 'SingleIdTokenIndexer'}
#  	 right_lemma_char: TextField of length 18 with text:
#  		[qui1, non, ego, interficio, ab, uulua, ut4, fio, ego, mater, meus, sepulcrum, et2, uulua, is,
# 		concipio, aeternus, .]
#  		and TokenIndexers : {'lemma_char': 'TokenCharactersIndexer'}
#  	 right_label: LabelField with label: positive in namespace: 'labels'.
#  	 right_metadata: MetadataField (print field.metadata to see specific information).
